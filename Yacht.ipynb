# %% [markdown]
# # Imports and Settings

# %%
import numpy as np
import torch
import pandas as pd
from torch.utils.data import DataLoader
import sys
from time import process_time as timer
import matplotlib.pyplot as plt
from tqdm import tqdm
from laplace import Laplace
from utils.dataset import get_dataset
from utils.models import get_mlp
from utils.pytorch_learning import fit_map
from utils.metrics import *
import glob
import os
import re

# %%
params = {
        "num_inducing": 20,
        "bnn_structure": [50, 50],
        "MAP_lr": 0.001,
        "MAP_iterations": 3000,
        "lr": 0.001,    # 0.01 o 0.001 
        "epochs": 200,    # Echar un vistazo a loss y ver si se estabiliza (a lo mejor converge con 50 épocas)
        "activation": torch.nn.Tanh,
        "device": "cpu",
        "dtype": torch.float64,
        "seed": 2147483647,
        "bb_alpha": 0,
        "prior_std": 1,
        "ll_std": 1,
        "batch_size": 100
}

# %%
torch.manual_seed(params["seed"])
dataset = get_dataset("Yacht", random_state=params["seed"])

# %%
# Ruta base de tu carpeta energy
base_path = "yacht"

# Patrón para encontrar todos los archivos *_metrics_fold_*.csv
pattern = os.path.join(base_path, "*_metrics_fold_*.csv")
files = glob.glob(pattern)

# Diccionario para almacenar los DataFrames por método
method_dfs = {}

# Expresión regular para extraer método y número de fold
regex = re.compile(r"([^/\\]+)_metrics_fold_(\d+)\.csv$")

for file in files:
    match = regex.search(file)
    if match:
        method = match.group(1)  # p.ej., "kron" o "lastlayer_lla"
        fold = int(match.group(2))

        # Leer el CSV
        df = pd.read_csv(file)

        # Añadir columna de fold
        df["fold"] = fold

        # Guardar en el diccionario
        if method not in method_dfs:
            method_dfs[method] = []
        method_dfs[method].append(df)

# Convertir cada lista de DataFrames en un único DataFrame por método
for method in method_dfs:
    method_df = pd.concat(method_dfs[method], ignore_index=True)
    # Ordenar por fold para que la tabla esté limpia
    method_df = method_df.sort_values("fold").reset_index(drop=True)
    method_dfs[method] = method_df

# Ahora puedes acceder a cada tabla así:
for method, df in method_dfs.items():
    print(f"\n--- Resultados para {method} ---")
    print(df)
# Out:
# --- Resultados para lastlayer_lla ---
#         RMSE       NLL      Q-10      Q-20      Q-30      Q-40      Q-50  \
# 0   1.021946  1.669867  0.125000  0.187500  0.312500  0.812500  0.875000
# 1   0.901887  1.569234  0.125000  0.375000  0.562500  0.812500  0.812500
# 2   0.761602  1.518270  0.437500  0.687500  0.812500  0.875000  0.875000
# 3   1.461406  1.835672  0.250000  0.375000  0.500000  0.562500  0.625000
# 4   1.221574  1.724367  0.000000  0.062500  0.250000  0.375000  0.687500
# 5   0.961766  1.636320  0.000000  0.312500  0.437500  0.687500  0.750000
# 6   3.733444  3.964162  0.062500  0.125000  0.437500  0.625000  0.750000
# 7   0.947635  1.632331  0.312500  0.312500  0.375000  0.500000  0.687500
# 8   2.046393  2.160442  0.200000  0.466667  0.533333  0.600000  0.666667
# 9   1.280551  1.706040  0.133333  0.133333  0.466667  0.666667  0.866667
# 10  2.994965  2.986474  0.200000  0.466667  0.666667  0.733333  0.733333
# 11  1.964126  2.086225  0.133333  0.333333  0.400000  0.800000  0.800000
# 12  1.108950  1.636234  0.133333  0.533333  0.666667  0.666667  0.666667
# 13  0.849712  1.574370  0.266667  0.466667  0.600000  0.800000  0.866667
# 14  1.623178  1.892537  0.200000  0.333333  0.533333  0.733333  0.733333
# 15  0.691691  1.511870  0.400000  0.600000  0.800000  0.866667  0.933333
# 16  1.315305  1.748784  0.466667  0.666667  0.666667  0.733333  0.866667
# 17  2.382020  2.402883  0.200000  0.333333  0.533333  0.600000  0.600000
# 18  3.328468  3.484432  0.200000  0.466667  0.666667  0.733333  0.866667
# 19  1.649817  1.900500  0.266667  0.533333  0.733333  0.800000  0.800000
#
#         Q-60      Q-70      Q-80      Q-90       CQM      CRPS  fold
# 0   0
#
#         Q-60      Q-70      Q-80      Q-90       CQM      CRPS  fold
# 0   0.937500  1.000000  1.000000  1.000000  0.215000  0.697273     1
# 1   0.937500  1.000000  1.000000  1.000000  0.256250  0.629156     2
# 2   0.937500  1.000000  1.000000  1.000000  0.343750  0.588440     3
# 3   0.937500  0.937500  0.937500  1.000000  0.200000  0.831441     4
# 4   0.875000  1.000000  1.000000  1.000000  0.185000  0.773764     5
# 5   0.937500  1.000000  1.000000  1.000000  0.207500  0.674685     6
# 6   0.750000  0.812500  0.812500  0.875000  0.131250  1.608612     7
# 7   1.000000  1.000000  1.000000  1.000000  0.250000  0.707308     8
# 8   0.866667  0.933333  0.933333  0.933333  0.196667  0.998163     9
# 9   0.866667  0.933333  0.933333  1.000000  0.210000  0.752996    10
# 10  0.733333  0.733333  0.800000  0.933333  0.183333  1.393766    11
# 11  0.933333  0.933333  0.933333  0.933333  0.223333  0.965850    12
# 12  0.933333  0.933333  0.933333  1.000000  0.223333  0.681561    13
# 13  0.933333  1.000000  1.000000  1.000000  0.276667  0.622269    14
# 14  0.866667  0.933333  1.000000  1.000000  0.236667  0.869844    15
# 15  1.000000  1.000000  1.000000  1.000000  0.336667  0.558626    16
# 16  0.933333  0.933333  0.933333  1.000000  0.290000  0.747123    17
# 17  0.733333  0.800000  0.800000  0.866667  0.143333  1.212945    18
# 18  0.866667  0.866667  0.866667  0.866667  0.230000  1.413094    19
# 19  0.866667  0.866667  0.933333  1.000000  0.263333  0.820447    20

# %%
plt.figure(figsize=(8, 6))

for method, df in method_dfs.items():
    if "CQM" in df.columns and "fold" in df.columns:
        plt.plot(df["fold"], df["CQM"], marker="o", label=method)

plt.xlabel("Fold")
plt.ylabel("CQM")
plt.title("Comparación de CQM por fold entre métodos")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Extraer datos de CQM para todos los métodos disponibles
data = []
labels = []

for method, df in method_dfs.items():
    if "CQM" in df.columns:  # Asegurarse de que existe la métrica
        data.append(df["CQM"])
        labels.append(method)

plt.figure(figsize=(8, 6))
plt.boxplot(data, tick_labels=labels, patch_artist=True)

plt.ylabel("CQM")
plt.title("Comparación de CQM entre métodos")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
for method, df in method_dfs.items():
    if "CQM" in df.columns:
        mean_cqm = df["CQM"].mean()
        std_cqm = df["CQM"].std() / np.sqrt(len(df))
        print(f"{method}: CQM media = {mean_cqm:.4f}, Desviación estándar = {std_cqm:.4f}")
# Out:
# lastlayer_lla: CQM media = 0.1772, Desviación estándar = 0.0129
# lla: CQM media = 0.2276, Desviación estándar = 0.0124
# kron: CQM media = 0.2288, Desviación estándar = 0.0129
# qla: CQM media = 0.2301, Desviación estándar = 0.0123

# %%
plt.figure(figsize=(8, 6))

for method, df in method_dfs.items():
    if "CRPS" in df.columns and "fold" in df.columns:
        plt.plot(df["fold"], df["CRPS"], marker="o", label=method)

plt.xlabel("Fold")
plt.ylabel("CRPS")
plt.title("Comparación de CRPS por fold entre métodos")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
data = []
labels = []

for method, df in method_dfs.items():
    if "CRPS" in df.columns:  # Asegurarse de que existe la métrica
        data.append(df["CRPS"])
        labels.append(method)

plt.figure(figsize=(8, 6))
plt.boxplot(data, tick_labels=labels, patch_artist=True)

plt.ylabel("CRPS")
plt.title("Comparación de CRPS entre métodos")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
for method, df in method_dfs.items():
    if "CRPS" in df.columns:
        mean_crps = df["CRPS"].mean()
        std_crps = df["CRPS"].std() / np.sqrt(len(df))
        print(f"{method}: CRPS media = {mean_crps:.4f}, Desviación estándar = {std_crps:.4f}")
# Out:
# lastlayer_lla: CRPS media = 0.8529, Desviación estándar = 0.0787
# lla: CRPS media = 0.8828, Desviación estándar = 0.0697
# kron: CRPS media = 0.8902, Desviación estándar = 0.0701
# qla: CRPS media = 0.8774, Desviación estándar = 0.0674

# %%
plt.figure(figsize=(8, 6))

for method, df in method_dfs.items():
    if "NLL" in df.columns and "fold" in df.columns:
        plt.plot(df["fold"], df["NLL"], marker="o", label=method)

plt.xlabel("Fold")
plt.ylabel("NLL")
plt.title("Comparación de NLL por fold entre métodos")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
data = []
labels = []

for method, df in method_dfs.items():
    if "NLL" in df.columns:  # Asegurarse de que existe la métrica
        data.append(df["NLL"])
        labels.append(method)

plt.figure(figsize=(8, 6))
plt.boxplot(data, tick_labels=labels, patch_artist=True)

plt.ylabel("NLL")
plt.title("Comparación de NLL entre métodos")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
for method, df in method_dfs.items():
    if "NLL" in df.columns:
        mean_nll = df["NLL"].mean()
        std_nll = df["NLL"].std() / np.sqrt(len(df))
        print(f"{method}: NLL media = {mean_nll:.4f}, Desviación estándar = {std_nll:.4f}")
# Out:
# lastlayer_lla: NLL media = 2.0321, Desviación estándar = 0.1524
# lla: NLL media = 1.9414, Desviación estándar = 0.0567
# kron: NLL media = 1.9572, Desviación estándar = 0.0618
# qla: NLL media = 1.9164, Desviación estándar = 0.0442
