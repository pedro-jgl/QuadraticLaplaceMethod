# %% [markdown]
# # Imports and Settings

# %%
import numpy as np
import torch
import pandas as pd
from torch.utils.data import DataLoader
import sys
from time import process_time as timer
import matplotlib.pyplot as plt
from tqdm import tqdm
from laplace import Laplace
from utils.dataset import get_dataset
from utils.models import get_mlp
from utils.pytorch_learning import fit_map
from utils.metrics import *
import glob
import os
import re

# %%
params = {
        "num_inducing": 20,
        "bnn_structure": [50, 50],
        "MAP_lr": 0.001,
        "MAP_iterations": 3000,
        "lr": 0.001,    # 0.01 o 0.001 
        "epochs": 200,    # Echar un vistazo a loss y ver si se estabiliza (a lo mejor converge con 50 épocas)
        "activation": torch.nn.Tanh,
        "device": "cpu",
        "dtype": torch.float64,
        "seed": 2147483647,
        "bb_alpha": 0,
        "prior_std": 1,
        "ll_std": 1,
        "batch_size": 100
}

# %%
torch.manual_seed(params["seed"])
dataset = get_dataset("Yacht", random_state=params["seed"])

# %%
# Ruta base de tu carpeta energy
base_path = "yacht"

# Patrón para encontrar todos los archivos *_metrics_fold_*.csv
pattern = os.path.join(base_path, "*_metrics_fold_*.csv")
files = glob.glob(pattern)

# Diccionario para almacenar los DataFrames por método
method_dfs = {}

# Expresión regular para extraer método y número de fold
regex = re.compile(r"([^/\\]+)_metrics_fold_(\d+)\.csv$")

for file in files:
    match = regex.search(file)
    if match:
        method = match.group(1)  # p.ej., "kron" o "lastlayer_lla"
        fold = int(match.group(2))

        # Leer el CSV
        df = pd.read_csv(file)

        # Añadir columna de fold
        df["fold"] = fold

        # Guardar en el diccionario
        if method not in method_dfs:
            method_dfs[method] = []
        method_dfs[method].append(df)

# Convertir cada lista de DataFrames en un único DataFrame por método
for method in method_dfs:
    method_df = pd.concat(method_dfs[method], ignore_index=True)
    # Ordenar por fold para que la tabla esté limpia
    method_df = method_df.sort_values("fold").reset_index(drop=True)
    method_dfs[method] = method_df

# Ahora puedes acceder a cada tabla así:
for method, df in method_dfs.items():
    print(f"\n--- Resultados para {method} ---")
    print(df)
# Out:
# --- Resultados para lastlayer_lla ---
#         RMSE        NLL      Q-10      Q-20      Q-30      Q-40      Q-50  \
# 0   1.021946   4.161908  0.000000  0.062500  0.062500  0.125000  0.125000
# 1   0.901887   2.458693  0.000000  0.125000  0.125000  0.125000  0.125000
# 2   0.761602   1.481830  0.062500  0.062500  0.375000  0.437500  0.437500
# 3   1.461406   7.342769  0.000000  0.000000  0.062500  0.125000  0.250000
# 4   1.221574   6.826353  0.000000  0.000000  0.000000  0.000000  0.000000
# 5   0.961766   4.722689  0.000000  0.000000  0.000000  0.000000  0.000000
# 6   3.733444  32.300047  0.062500  0.062500  0.062500  0.062500  0.062500
# 7   0.947635   3.671105  0.062500  0.125000  0.312500  0.312500  0.312500
# 8   2.046393  11.110864  0.066667  0.133333  0.133333  0.133333  0.200000
# 9   1.280551   6.714398  0.000000  0.066667  0.133333  0.133333  0.133333
# 10  2.994965  20.049043  0.066667  0.066667  0.066667  0.066667  0.133333
# 11  1.964126   8.727561  0.000000  0.000000  0.000000  0.133333  0.133333
# 12  1.108950   3.930579  0.000000  0.000000  0.000000  0.066667  0.133333
# 13  0.849712   2.369899  0.000000  0.066667  0.266667  0.266667  0.266667
# 14  1.623178   6.199590  0.066667  0.133333  0.133333  0.133333  0.200000
# 15  0.691691   1.308955  0.066667  0.133333  0.333333  0.400000  0.400000
# 16  1.315305   7.098400  0.133333  0.266667  0.333333  0.400000  0.533333
# 17  2.382020  17.306698  0.133333  0.200000  0.200000  0.200000  0.200000
# 18  3.328468  29.566061  0.133333  0.133333  0.200000  0.200000  0.266667
# 19  1.649817   6.617763  0.066667  0.133333  0.200000  0.200000  0.266667
#
#         Q-60      Q-70      Q-80      Q-90       CQM      CRPS  fold
# 0   0
#
#         Q-60      Q-70      Q-80      Q-90       CQM      CRPS  fold
# 0   0.437500  0.687500  0.812500  0.937500  0.078750  0.577083     1
# 1   0.812500  0.875000  0.875000  1.000000  0.087500  0.466839     2
# 2   0.875000  0.937500  1.000000  1.000000  0.231250  0.382999     3
# 3   0.437500  0.562500  0.625000  0.812500  0.081250  0.741787     4
# 4   0.437500  0.437500  0.750000  0.812500  0.162500  0.709519     5
# 5   0.562500  0.625000  0.687500  0.875000  0.081250  0.570572     6
# 6   0.500000  0.562500  0.750000  0.750000  0.100000  1.564041     7
# 7   0.562500  0.625000  0.750000  0.937500  0.056250  0.595822     8
# 8   0.533333  0.733333  0.800000  0.933333  0.043333  0.880751     9
# 9   0.733333  0.733333  0.800000  0.866667  0.043333  0.645960    10
# 10  0.733333  0.733333  0.733333  0.800000  0.083333  1.270894    11
# 11  0.666667  0.866667  0.933333  0.933333  0.063333  0.815159    12
# 12  0.733333  0.733333  0.800000  0.933333  0.056667  0.544465    13
# 13  0.666667  0.800000  0.933333  0.933333  0.076667  0.456450    14
# 14  0.733333  0.800000  0.933333  1.000000  0.076667  0.723407    15
# 15  0.866667  0.933333  1.000000  1.000000  0.163333  0.343159    16
# 16  0.733333  0.733333  0.933333  0.933333  0.170000  0.586233    17
# 17  0.600000  0.666667  0.666667  0.733333  0.056667  1.152006    18
# 18  0.666667  0.866667  0.866667  0.866667  0.063333  1.289279    19
# 19  0.800000  0.800000  0.800000  0.866667  0.076667  0.651668    20

# %%
plt.figure(figsize=(8, 6))

for method, df in method_dfs.items():
    if "CQM" in df.columns and "fold" in df.columns:
        plt.plot(df["fold"], df["CQM"], marker="o", label=method)

plt.xlabel("Fold")
plt.ylabel("CQM")
plt.title("Comparación de CQM por fold entre métodos")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Extraer datos de CQM para todos los métodos disponibles
data = []
labels = []

for method, df in method_dfs.items():
    if "CQM" in df.columns:  # Asegurarse de que existe la métrica
        data.append(df["CQM"])
        labels.append(method)

plt.figure(figsize=(8, 6))
plt.boxplot(data, tick_labels=labels, patch_artist=True)

plt.ylabel("CQM")
plt.title("Comparación de CQM entre métodos")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
for method, df in method_dfs.items():
    if "CQM" in df.columns:
        mean_cqm = df["CQM"].mean()
        std_cqm = df["CQM"].std()
        print(f"{method}: CQM media = {mean_cqm:.4f}, Desviación estándar = {std_cqm:.4f}")
# Out:
# lastlayer_lla: CQM media = 0.2430, Desviación estándar = 0.0948
# lla: CQM media = 0.0928, Desviación estándar = 0.0484
# kron: CQM media = 0.1233, Desviación estándar = 0.0675
# qla: CQM media = 0.0926, Desviación estándar = 0.0497

# %%
plt.figure(figsize=(8, 6))

for method, df in method_dfs.items():
    if "CRPS" in df.columns and "fold" in df.columns:
        plt.plot(df["fold"], df["CRPS"], marker="o", label=method)

plt.xlabel("Fold")
plt.ylabel("CRPS")
plt.title("Comparación de CRPS por fold entre métodos")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Extraer datos de CQM para todos los métodos disponibles
data = []
labels = []

for method, df in method_dfs.items():
    if "CRPS" in df.columns:  # Asegurarse de que existe la métrica
        data.append(df["CRPS"])
        labels.append(method)

plt.figure(figsize=(8, 6))
plt.boxplot(data, tick_labels=labels, patch_artist=True)

plt.ylabel("CRPS")
plt.title("Comparación de CRPS entre métodos")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
for method, df in method_dfs.items():
    if "CRPS" in df.columns:
        mean_crps = df["CRPS"].mean()
        std_crps = df["CRPS"].std()
        print(f"{method}: CRPS media = {mean_crps:.4f}, Desviación estándar = {std_crps:.4f}")
# Out:
# lastlayer_lla: CRPS media = 0.8697, Desviación estándar = 0.3955
# lla: CRPS media = 0.7631, Desviación estándar = 0.3421
# kron: CRPS media = 0.7991, Desviación estándar = 0.3358
# qla: CRPS media = 0.7484, Desviación estándar = 0.3286

# %%
plt.figure(figsize=(8, 6))

for method, df in method_dfs.items():
    if "NLL" in df.columns and "fold" in df.columns:
        plt.plot(df["fold"], df["NLL"], marker="o", label=method)

plt.xlabel("Fold")
plt.ylabel("NLL")
plt.title("Comparación de NLL por fold entre métodos")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
data = []
labels = []

for method, df in method_dfs.items():
    if "NLL" in df.columns:  # Asegurarse de que existe la métrica
        data.append(df["NLL"])
        labels.append(method)

plt.figure(figsize=(8, 6))
plt.boxplot(data, tick_labels=labels, patch_artist=True)

plt.ylabel("NLL")
plt.title("Comparación de NLL entre métodos")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
for method, df in method_dfs.items():
    if "NLL" in df.columns:
        mean_nll = df["NLL"].mean()
        std_nll = df["NLL"].std()
        print(f"{method}: NLL media = {mean_nll:.4f}, Desviación estándar = {std_nll:.4f}")
# Out:
# lastlayer_lla: NLL media = 9.1983, Desviación estándar = 8.8518
# lla: NLL media = 1.6159, Desviación estándar = 0.5267
# kron: NLL media = 1.7518, Desviación estándar = 0.4700
# qla: NLL media = 1.4832, Desviación estándar = 0.3481
